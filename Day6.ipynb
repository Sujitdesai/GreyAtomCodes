# %% [markdown]
# <a href="https://colab.research.google.com/github/Sujitdesai/GreyAtomCodes/blob/master/Day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn
import pandas as pd

# %%
df = pd.read_csv('WorldHappiness2018_Data.csv')

# %%
df.head()
# Out:
#    Rank      Country  Score  ...  Generosity  Perceptions_Of_Corruption  Residual
# 0     1      Finland  7.632  ...       0.192                      0.393     2.988
# 1     2       Norway  7.594  ...       0.286                      0.340     2.723
# 2     3      Denmark  7.555  ...       0.284                      0.408     2.779
# 3     4      Iceland  7.495  ...       0.353                      0.138     2.564
# 4     5  Switzerland  7.487  ...       0.256                      0.357     2.675
#
# [5 rows x 10 columns]

# %%
x = df['Rank']
x
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 151    152
# 152    153
# 153    154
# 154    155
# 155    156
# Name: Rank, Length: 156, dtype: int64

# %%
y=df['Score']

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)
plt.show()

# %%
z = df.GDP_Per_Capita
z
# Out:
# 0      1.305
# 1      1.456
# 2      1.351
# 3      1.343
# 4      1.420
#        ...
# 151    0.442
# 152    0.455
# 153    0.337
# 154    0.024
# 155    0.091
# Name: GDP_Per_Capita, Length: 156, dtype: float64

# %%
c = df.Healthy_Life_Expectancy
c
# Out:
# 0      0.874
# 1      0.861
# 2      0.868
# 3      0.914
# 4      0.927
#        ...
# 151    0.343
# 152    0.381
# 153    0.177
# 154    0.010
# 155    0.145
# Name: Healthy_Life_Expectancy, Length: 156, dtype: float64

# %%
plt.title('rank vs gdp and rank vs life expectancy')
plt.plot(x,c,color="green")
plt.plot(x,z,color="red")
plt.xlabel('Rank')
plt.legend('TB',loc='upper left')
plt.show()

# %%
import seaborn as sns
sns.set()
plt.hist(y,linewidth=1.2,color='red')
plt.show()

# %%
q = df.Score.apply(int).value_counts()

# %%
q
# Out:
# 5    50
# 4    41
# 6    34
# 3    17
# 7    13
# 2     1
# Name: Score, dtype: int64

# %%
print(q.index)
# Out:
# Int64Index([5, 4, 6, 3, 7, 2], dtype='int64')

# %%
plt.bar(q.index,q)
plt.xlabel('Score')
plt.ylabel('Rank')
# Out:
# Text(0, 0.5, 'Rank')

# %%
plt.pie(q)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fc783540cc0>,
# ...
#  [Text(0.5879123774934254, 0.9297091138576777, ''),
#   Text(-1.0501929743714777, 0.32725329116876567, ''),
#   Text(-0.39006530537605527, -1.0285178936420527, ''),
#   Text(0.6783908269313558, -0.8659017761474979, ''),
#   Text(1.0501929820313936, -0.32725326658722487, ''),
#   Text(1.099776954016227, -0.02215065269444223, '')])

# %%
plt.scatter(z,y)

# %%
plt.boxplot(y)
plt.boxplot(c)
plt.show()

# %%
import numpy as np
m=np.random.randint(1,100,9).reshape(3,3)
m
# Out:
# array([[21, 19, 96],
#        [40,  9, 66],
#        [13, 10, 67]])

# %%
sns.heatmap(m,linewidths=0.5) #heatmap=corelation

# %%
df
# Out:
#      Rank                   Country  ...  Perceptions_Of_Corruption  Residual
# 0       1                   Finland  ...                      0.393     2.988
# 1       2                    Norway  ...                      0.340     2.723
# 2       3                   Denmark  ...                      0.408     2.779
# 3       4                   Iceland  ...                      0.138     2.564
# 4       5               Switzerland  ...                      0.357     2.675
# ..    ...                       ...  ...                        ...       ...
# 151   152                     Yemen  ...                      0.064     1.170
# 152   153                  Tanzania  ...                      0.097     0.725
# 153   154               South Sudan  ...                      0.106     1.796
# 154   155  Central African Republic  ...                      0.038     2.526
# 155   156                   Burundi  ...                      0.076     1.828
#
# [156 rows x 10 columns]

# %%
r = (df[['Score','GDP_Per_Capita','Healthy_Life_Expectancy','Freedom_To_Make_Life_Choices']])
r.corr()
sns.heatmap(r.corr())
plt.show()

# %%
plt.pie(q)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
sns.heatmap(df.corr())

# %%
import seaborn as sns
sns.violinplot(df[['GDP_Per_Capita','Healthy_Life_Expectancy','Freedom_To_Make_Life_Choices']])

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
ax = sns.violinplot(x = ["total_bill"])

# %%
ax = sns.violinplot( x= "day",y="total_bill",data=tips)

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ax = sns.violinplot( x= "day",y="total_bill",hue="smoker",data=tips,split=True) #hue=different category

# %%
df['Country']
# Out:
# 0                       Finland
# 1                        Norway
# 2                       Denmark
# 3                       Iceland
# 4                   Switzerland
#                  ...
# 151                       Yemen
# 152                    Tanzania
# 153                 South Sudan
# 154    Central African Republic
# 155                     Burundi
# Name: Country, Length: 156, dtype: object

# %%
df['Country'].value_counts()
# Out:
# Russia                     1
# Namibia                    1
# Latvia                     1
# Ireland                    1
# Moldova                    1
#                           ..
# Kuwait                     1
# Syria                      1
# Saudi Arabia               1
# Palestinian Territories    1
# Denmark                    1
# Name: Country, Length: 156, dtype: int64

# %%
ax = sns.violinplot(x="day", y="total_bill", hue="sex",
                    data=tips, palette="Set2", split=True,
                    scale="count", inner="quartile")

# %%
g = sns.catplot(x="sex", y="total_bill",
                hue="smoker", col="time",
                data=tips, kind="violin", split=True,
                height=4, aspect=.7);

# %%
#grouped bar chart
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('dark_background')

t = np.arange(0.0, 1.0 + 0.01, 0.01)
s = np.cos(2 * 2*np.pi * t)
t[41:60] = np.nan

plt.subplot(1, 2, 1) #row,column,no.of grphs
plt.plot(t, s, '-', lw=2)

plt.xlabel('time (s)')
plt.ylabel('voltage (mV)')
plt.title('A sine wave with a gap of NaNs between 0.4 and 0.6')
plt.grid(True)

plt.subplot(1, 2, 2)
t[0] = np.nan
t[-1] = np.nan
plt.plot(t, s, '-', lw=2)
plt.title('Also with NaN in first and last point')

plt.xlabel('time (s)')
plt.ylabel('more nans')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations

# %%
df = pd.read_csv('WorldHappiness2018_Data.csv')
x = df['Rank']
y = df['Score']
fig, axs=plt.subplots(2,2) #
axs[0,0].plot(x,y)
#axs[0,0].config/set_title('Axis[0,0]')
axs[0,1].plot(x,y,'tab:orange')
axs[0,1].set_title('Axis[0,1]')
axs[1,0].plot(x,y,'tab:green')
axs[1,0].set_title('Axis[1,0]')
axs[1,1].plot(x,y,'tab:red')
axs[1,1].set_title('Axis[1,1]')
plt.show()

# %%
for i in range(1,9):
  plt.subplot(4,2,i)
  plt.plot(x,y)
  i=i+1
plt.show()
